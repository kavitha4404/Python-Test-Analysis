# %%
# loading the packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataset
df = pd.read_csv("Aadhar_data.csv")
df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12188\175742378.py:2: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Aadhar_data.csv")
#                                              Registrar  \
# 0                                       Allahabad Bank
# 1                                       Allahabad Bank
# 2                                       Allahabad Bank
# 3                                       Allahabad Bank
# 4                                       Allahabad Bank
# ...                                                ...
# 440813  Women and Child Development Govt. of Jharkhand
# 440814  Women and Child Development Govt. of Jharkhand
# 440815  Women and Child Development Govt. of Jharkhand
# 440816  Women and Child Development Govt. of Jharkhand
# 440817  Women and Child Development Govt. of Jharkhand
#
#                            Enrolment Agency          State   District  \
# ...

# %%
# checkin for nullvalue
df.isnull().sum()
# Out:
# Registrar                            0
# Enrolment Agency                     0
# State                                0
# District                             0
# Sub District                         0
# Pin Code                             0
# Gender                               0
# Age                                  0
# Aadhaar generated                    0
# Enrolment Rejected                   0
# Residents providing email            0
# Residents providing mobile number    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440818 entries, 0 to 440817
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Registrar                          440818 non-null  object
#  1   Enrolment Agency                   440818 non-null  object
#  2   State                              440818 non-null  object
#  3   District                           440818 non-null  object
#  4   Sub District                       440818 non-null  object
#  5   Pin Code                           440818 non-null  object
#  6   Gender                             440818 non-null  object
#  7   Age                                440818 non-null  int64
#  8   Aadhaar generated                  440818 non-null  int64
#  9   Enrolment Rejected                 440818 non-null  int64
#  10  Residents providing email          440818 non-null  int64
# ...

# %%
# display the columns
df.columns
# Out:
# Index(['Registrar', 'Enrolment Agency', 'State', 'District', 'Sub District',
#        'Pin Code', 'Gender', 'Age', 'Aadhaar generated', 'Enrolment Rejected',
#        'Residents providing email', 'Residents providing mobile number'],
#       dtype='object')

# %%
# display the top 5 records
top_5_records=df.head(5)
print('top_5_records')
top_5_records
# Out:
# top_5_records
#         Registrar                     Enrolment Agency          State  \
# 0  Allahabad Bank                A-Onerealtors Pvt Ltd  Uttar Pradesh
# 1  Allahabad Bank         Asha Security Guard Services  Uttar Pradesh
# 2  Allahabad Bank                    SGS INDIA PVT LTD  Uttar Pradesh
# 3  Allahabad Bank  Sri Ramraja Sarkar Lok Kalyan Trust  Uttar Pradesh
# 4  Allahabad Bank                   Transmoovers India  Uttar Pradesh
#
#     District Sub District Pin Code Gender  Age  Aadhaar generated  \
# 0  Allahabad         Meja   212303      F    7                  1
# 1  Sonbhadra  Robertsganj   231213      M    8                  1
# 2  Sultanpur    Sultanpur   227812      F   13                  1
# 3     Shamli       Shamli   247775      M    6                  1
# 4  Gorakhpur     Sahjanwa   273001      M    8                  1
#
#    Enrolment Rejected  Residents providing email  \
# 0                   0                          0
# ...

# %%
# display the bottom 5 records
bottom_5_records=df.head(5)
print('bottom_5_records')
bottom_5_records
# Out:
# bottom_5_records
#         Registrar                     Enrolment Agency          State  \
# 0  Allahabad Bank                A-Onerealtors Pvt Ltd  Uttar Pradesh
# 1  Allahabad Bank         Asha Security Guard Services  Uttar Pradesh
# 2  Allahabad Bank                    SGS INDIA PVT LTD  Uttar Pradesh
# 3  Allahabad Bank  Sri Ramraja Sarkar Lok Kalyan Trust  Uttar Pradesh
# 4  Allahabad Bank                   Transmoovers India  Uttar Pradesh
#
#     District Sub District Pin Code Gender  Age  Aadhaar generated  \
# 0  Allahabad         Meja   212303      F    7                  1
# 1  Sonbhadra  Robertsganj   231213      M    8                  1
# 2  Sultanpur    Sultanpur   227812      F   13                  1
# 3     Shamli       Shamli   247775      M    6                  1
# 4  Gorakhpur     Sahjanwa   273001      M    8                  1
#
#    Enrolment Rejected  Residents providing email  \
# 0                   0                          0
# ...

# %%
# display the statistical data
df.describe()
# Out:
#                  Age  Aadhaar generated  Enrolment Rejected  \
# count  440818.000000      440818.000000       440818.000000
# mean       19.704368           1.601430            0.087510
# std        18.686811           3.391819            0.407087
# min         0.000000           0.000000            0.000000
# 25%         5.000000           1.000000            0.000000
# 50%        13.000000           1.000000            0.000000
# 75%        30.000000           1.000000            0.000000
# max       118.000000         391.000000           40.000000
#
#        Residents providing email  Residents providing mobile number
# count              440818.000000                      440818.000000
# mean                    0.044154                           1.054496
# std                     0.237212                           1.547764
# min                     0.000000                           0.000000
# 25%                     0.000000                           0.000000
# ...

# %% [markdown]
# ### 1. Find out the total number of cards approved by States.

# %%
# Group the data by 'State' and sum the 'Aadhaar generated' column for each state
cards_approved_by_states = df.groupby('State')['Aadhaar generated'].sum()
df1 = pd.DataFrame(cards_approved_by_states)
df1
# Out:
#                              Aadhaar generated
# State
# Andaman and Nicobar Islands                  5
# Andhra Pradesh                            5798
# Arunachal Pradesh                          913
# Assam                                     3213
# Bihar                                   162607
# Chandigarh                                 259
# Chhattisgarh                              6604
# Dadra and Nagar Haveli                     140
# Daman and Diu                              105
# Delhi                                     8426
# Goa                                       1167
# Gujarat                                  34844
# Haryana                                   6804
# Himachal Pradesh                          1547
# Jammu and Kashmir                         1234
# Jharkhand                                 9868
# Karnataka                                19764
# Kerala                                   15143
# Lakshadweep                                  4
# ...

# %% [markdown]
# ### 2. Find out the total number of cards Enrolment rejected by states.

# %%
# Group the data by 'State' and sum the 'Enrolment rejected' column for each state
cards_enrolment_rej_states = df.groupby('State')["Enrolment Rejected"].sum()
df1 = pd.DataFrame(cards_enrolment_rej_states)
df1
# Out:
#                              Enrolment Rejected
# State
# Andaman and Nicobar Islands                   2
# Andhra Pradesh                              373
# Arunachal Pradesh                            79
# Assam                                        28
# Bihar                                      7209
# Chandigarh                                    9
# Chhattisgarh                                380
# Dadra and Nagar Haveli                        3
# Daman and Diu                                 2
# Delhi                                       591
# Goa                                         127
# Gujarat                                    2500
# Haryana                                     532
# Himachal Pradesh                            123
# Jammu and Kashmir                           204
# Jharkhand                                   477
# Karnataka                                  1445
# Kerala                                      538
# ...

# %% [markdown]
# ### 3. Find out the total number of cards approved by Districts.

# %%
# Group the data by 'District' and sum the 'Aadhaar generated' column for each District
cards_approved_by_district = df.groupby('District')['Aadhaar generated'].sum()
df1 = pd.DataFrame(cards_approved_by_district)
df1
# Out:
#               Aadhaar generated
# District
# Adilabad                    265
# Agra                       2283
# Ahmadnagar                  476
# Ahmedabad                  4212
# Aizawl                     1095
# ...                         ...
# Wokha                        32
# Yadgir                      325
# Yamuna Nagar                197
# Yavatmal                    712
# Zunheboto                     8
#
# [664 rows x 1 columns]

# %% [markdown]
# ### 4. Find out the total number of cards rejected by Districts.

# %%
# Group the data by 'State' and sum the 'Enrolment rejected' column for each state
cards_enrolment_rej_District = df.groupby('District')["Enrolment Rejected"].sum()
df1 = pd.DataFrame(cards_enrolment_rej_District)
df1
# Out:
#               Enrolment Rejected
# District
# Adilabad                       7
# Agra                         137
# Ahmadnagar                    45
# Ahmedabad                    278
# Aizawl                       111
# ...                          ...
# Wokha                          2
# Yadgir                        28
# Yamuna Nagar                  11
# Yavatmal                      78
# Zunheboto                      0
#
# [664 rows x 1 columns]

# %% [markdown]
# ### 5.Total Count Gender Based

# %%
# Group the data by 'Gender' and count the number of occurrences for each gender
gender_count = df['Gender'].value_counts()
df1 = pd.DataFrame({"gender":gender_count.index,"count":gender_count.values})
df1
# Out:
#   gender   count
# 0      M  292798
# 1      F  148013
# 2      T       7

# %% [markdown]
# ### 6.Count Records age <25, age between 25 &35, age>45

# %%
# Defining the age categories
Age_Categories = {'age<25':(df['Age'] < 25).sum(),
                 'age(25-35)':((df['Age'] >= 25) & (df['Age'] <= 35)).sum(),
                 'age>45':(df['Age'] > 45).sum()}
# print the count of records for each age category
print(Age_Categories)
# Out:
# {'age<25': 296836, 'age(25-35)': 62512, 'age>45': 50610}

# %% [markdown]
# ### Correlation Between Attributes

# %%
df1 = df.corr()
sns.heatmap(df1,annot=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12188\4077343426.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1 = df.corr()
# <Axes: >

# %% [markdown]
# ### Box plot of Age by each Gender

# %%
sns.boxplot(y='Age',x='Gender',data=df)
plt.title("Box plot of Age by Gender")
plt.show()

# %% [markdown]
# ### Subplots On Age And Gender

# %%
# age
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
sns.histplot(df['Age'], bins=20, color='skyblue',edgecolor='blue')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
# gender
plt.subplot(1, 2, 2)
sns.histplot(df['Gender'],bins=20,color='red',edgecolor='purple')
plt.xlabel('Gender')
plt.title('Gender Distribution')
# Out:
# Text(0.5, 1.0, 'Gender Distribution')
