# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('auto_data')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
# converting a string value to an equivalent number value

# Convert the data type of 'horsepower' to int
df['horsepower'] =pd.to_numeric(df['horsepower'],errors='coerce')

# %%
# display the statistical data
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
# Display the top 5 records
top5_records=df.head(5)
print('The Top5 Records:')
top5_records
# Out:
# The Top5 Records:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
#  display the bottom 5 records
bottom5 = df.tail(5)
print('The Bottom5 Records:')
bottom5
# Out:
# The Bottom5 Records:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin             name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
# Displaying the Correlation between variables
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14412\3251389593.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
# Grouping the data by a categorical variable('origin') and calculating mean
grouped_data = df.groupby('origin').mean()
grouped_data
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14412\1106380029.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_data = df.groupby('origin').mean()
#               mpg  cylinders  displacement       weight  acceleration  \
# origin
# 1       20.083534   6.248996    245.901606  3361.931727     15.033735
# 2       27.891429   4.157143    109.142857  2423.300000     16.787143
# 3       30.450633   4.101266    102.708861  2221.227848     16.172152
#
#         model_year
# origin
# 1        75.610442
# 2        75.814286
# 3        77.443038

# %%
# Barplot
sns.barplot(x=grouped_data.index, y='mpg', data=grouped_data)
plt.title('Mean MPG by Origin')
plt.xlabel('Origin')
plt.ylabel('Mean MPG')
plt.show()

# %%
# barplot
sns.barplot(x=grouped_data.index, y='displacement', data=grouped_data)
plt.title('Mean displacement by Origin')
plt.xlabel('Origin')
plt.ylabel('Mean diplacement')
plt.show()

# %%
# line plot
sns.lineplot(x=grouped_data.index, y='weight', data=grouped_data)
plt.title('Mean Weight by Origin')
plt.xlabel('Origin')
plt.ylabel('Mean Weight')
plt.show()

# %%
# boxplot
sns.boxplot(x=grouped_data.index, y='acceleration', data=grouped_data)
plt.title('Mean Weight by acceleration')
plt.xlabel('Origin')
plt.ylabel('Mean acceleration')
plt.show()

# %%
# The pair plot for mpg, weight,orign
sns.pairplot(df[['mpg','weight','origin']],hue='origin',size=4)
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Identify how many types of  cylinder vehicles

# %%
# Group by the 'cylinders' column and count the number of unique values
by_cylinders = df.groupby('cylinders')['name'].nunique()
num_cylinder_types = len(by_cylinders)
print("Number of unique cylinder types:", num_cylinder_types)
print("Cylinder types:", by_cylinders)
# Out:
# Number of unique cylinder types: 5
# Cylinder types: cylinders
# 3      4
# 4    161
# 5      3
# 6     63
# 8     82
# Name: name, dtype: int64

# %%
# Count the number of vehicles for each model year
vehicle_counts = df["model_year"].value_counts().sort_index()

# Display the results
df1 = pd.DataFrame({'model_year':vehicle_counts.index,'vehicle_count':vehicle_counts.values})
df1
# Out:
#     model_year  vehicle_count
# 0           70             29
# 1           71             28
# 2           72             28
# 3           73             40
# 4           74             27
# 5           75             30
# 6           76             34
# 7           77             28
# 8           78             36
# 9           79             29
# 10          80             29
# 11          81             29
# 12          82             31

# %%
# identify name where acceleration is greater than 15 and horsepower less than 170

# Filter the dataset
filtered_data= df[(df['acceleration'] > 15) & (df['horsepower'] < 170)]

# Access the 'name' column of the filtered rows
selected_names = filtered_data['name']
selected_names
# Out:
# 15                  plymouth duster
# 16                       amc hornet
# 17                    ford maverick
# 19     volkswagen 1131 deluxe sedan
# 20                      peugeot 504
#                    ...
# 392                chevrolet camaro
# 393                 ford mustang gl
# 394                       vw pickup
# 396                     ford ranger
# 397                      chevy s-10
# Name: name, Length: 211, dtype: object
